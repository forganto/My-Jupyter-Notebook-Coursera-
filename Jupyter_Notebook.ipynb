# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Mykhailo Sydorenko-Bielkin
# I am currently a student, but i want to become a data scientist

# %% [markdown]
# I am interested in data science because this knowledge will help me not only as a data scientist, but also in other professions.

# %% [markdown]
# This code divides the user-defined number by 2

# %%
user_number = input("Hello. Please type any number")
divided_number = float(user_number)/2
print("Your number (", user_number, ") was divided by 2 and you have", divided_number)
# Out:
# Hello. Please type any number 653
# Your number ( 653 ) was divided by 2 and you have 326.5

# %% [markdown]
# - My favourite softwares
#     * Unity
#     * Blender
#     * Visual Studio
#
# | Name | Favourite food | Disliked food |
# | --- | --- | --- |
# | Tom | ice cream | broccoli |
# | John | pizza | mushrooms |
# | Alex | apple pie | tomatoes |
#
# *Cute kittens*
# ![cute-kittens.png](attachment:4fd2fa70-0eed-4936-8c46-dadc55f308b2.png)
